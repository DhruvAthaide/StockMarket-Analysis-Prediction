# %%
# Importing the Necessary Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Setting the Styles for the Graphs
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# Dependencies for Reading the Stock from Yahoo Finance
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

# %%
# All the Stocks that are to be Analyzed
tech_list = ['ONGC.NS', 'AAPL', 'JETFREIGHT.NS', 'ITC.NS']

# Setting the start and end date for data analysis
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)
    
# Correlating the Compnay Symbols with the Company Names
company_list = [globals()[stock] for stock in tech_list]
company_name = ["ONGC", "APPLE", "JETFREIGHT", "ITC"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
    
df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-06-21  425.000000  425.299988  418.549988  419.600006  419.600006
# 2024-06-24  420.000000  423.950012  420.000000  423.299988  423.299988
# 2024-06-25  423.000000  424.000000  419.750000  423.299988  423.299988
# 2024-06-26  423.000000  426.399994  422.049988  423.950012  423.950012
# 2024-06-27  423.950012  427.250000  421.100006  425.600006  425.600006
# 2024-06-28  425.500000  428.000000  423.500000  424.899994  424.899994
# 2024-07-01  426.299988  430.250000  424.649994  429.049988  429.049988
# 2024-07-02  430.000000  430.649994  422.549988  425.500000  425.500000
# ...

# %%
# Summary Stats about the First Stock Symbol
company_list[0].describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  246.000000  246.000000  246.000000  246.000000  246.000000
# mean   224.708130  227.379877  221.473578  224.324594  220.498752
# std     43.047417   43.881587   41.688214   42.697615   45.864188
# min    162.000000  162.899994  160.000000  161.199997  153.823532
# 25%    185.000000  186.349998  183.749996  184.775002  176.817123
# 50%    207.250000  210.599998  204.625000  207.800003  204.802528
# 75%    270.624992  273.949997  266.575005  270.162498  269.800003
# max    288.700012  292.950012  284.000000  286.100006  286.100006
#
#              Volume
# count  2.460000e+02
# mean   1.563451e+07
# std    1.169465e+07
# min    2.240015e+06
# 25%    8.766594e+06
# 50%    1.216743e+07
# 75%    1.916633e+07
# max    7.908254e+07

# %%
# General info about the First Stock Symbol
company_list[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 246 entries, 2023-07-04 to 2024-07-04
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          246 non-null    float64
#  1   High          246 non-null    float64
#  2   Low           246 non-null    float64
#  3   Close         246 non-null    float64
#  4   Adj Close     246 non-null    float64
#  5   Volume        246 non-null    int64
#  6   company_name  246 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.4+ KB

# %%
# Summary Stats about the First Stock Symbol
company_list[1].describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   184.401468  186.006270  182.938770  184.491706  184.026902
# std     11.341931   11.526205   11.221791   11.404021   11.456076
# min    165.350006  166.399994  164.080002  165.000000  164.776505
# 25%    175.277496  177.052502  173.700005  175.370007  174.801846
# 50%    183.735001  185.119995  182.014999  183.989998  183.502815
# 75%    191.452503  192.684998  190.247505  191.477497  190.970264
# max    220.000000  221.550003  219.029999  221.550003  221.550003
#
#              Volume
# count  2.520000e+02
# mean   6.033096e+07
# std    2.474195e+07
# min    2.404830e+07
# 25%    4.678918e+07
# 50%    5.368500e+07
# 75%    6.615335e+07
# max    2.464214e+08

# %%
# General info about the First Stock Symbol
company_list[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2023-07-05 to 2024-07-03
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          252 non-null    float64
#  1   High          252 non-null    float64
#  2   Low           252 non-null    float64
#  3   Close         252 non-null    float64
#  4   Adj Close     252 non-null    float64
#  5   Volume        252 non-null    int64
#  6   company_name  252 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
# Summary Stats about the First Stock Symbol
company_list[2].describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  246.000000  246.000000  246.000000  246.000000  246.000000
# mean    12.604350   12.870610   12.218171   12.483780   12.483780
# std      1.872275    1.971757    1.774720    1.832853    1.832853
# min      9.300000    9.600000    9.200000    9.350000    9.350000
# 25%     10.750000   10.912500   10.412500   10.700000   10.700000
# 50%     13.175000   13.350000   12.550000   12.950000   12.950000
# 75%     13.987500   14.500000   13.647500   13.947500   13.947500
# max     16.500000   16.900000   15.500000   16.200001   16.200001
#
#              Volume
# count  2.460000e+02
# mean   2.370467e+05
# std    4.619861e+05
# min    0.000000e+00
# 25%    6.755775e+04
# 50%    1.270035e+05
# 75%    2.087138e+05
# max    4.915530e+06

# %%
# General info about the First Stock Symbol
company_list[2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 246 entries, 2023-07-04 to 2024-07-04
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          246 non-null    float64
#  1   High          246 non-null    float64
#  2   Low           246 non-null    float64
#  3   Close         246 non-null    float64
#  4   Adj Close     246 non-null    float64
#  5   Volume        246 non-null    int64
#  6   company_name  246 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.4+ KB

# %%
# Summary Stats about the First Stock Symbol
company_list[3].describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  246.000000  246.000000  246.000000  246.000000  246.000000
# mean   441.717682  444.872358  437.298983  440.721342  429.842432
# std     18.460194   18.540757   18.038392   18.378747   15.556839
# min    405.000000  406.500000  399.350006  403.350006  396.320557
# 25%    429.324997  431.750008  425.599991  428.637505  420.946266
# 50%    440.000000  442.550003  436.549988  439.199997  428.594940
# 75%    454.175011  457.000000  449.412506  452.425011  438.493240
# max    493.450012  499.700012  487.000000  492.149994  476.573608
#
#              Volume
# count  2.460000e+02
# mean   1.395750e+07
# std    1.036704e+07
# min    3.744754e+06
# 25%    8.195454e+06
# 50%    1.105556e+07
# 75%    1.589774e+07
# max    1.016124e+08

# %%
# General info about the First Stock Symbol
company_list[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 246 entries, 2023-07-04 to 2024-07-04
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          246 non-null    float64
#  1   High          246 non-null    float64
#  2   Low           246 non-null    float64
#  3   Close         246 non-null    float64
#  4   Adj Close     246 non-null    float64
#  5   Volume        246 non-null    int64
#  6   company_name  246 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 15.4+ KB

# %%
# Plotting the Historical Figure of Closing Prices for the Different Stock Symbols
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# Plotting the Volume of the Stocks being traded per day
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {tech_list[i - 1]}")
    
plt.tight_layout()

# %%
# Calculating Moving Average
ma_day = [10, 20, 50]

for ma in ma_day:
    for company in company_list:
        column_name = f"MA for {ma} days"
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        

# Plotting the data
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

# Plot for ONGC.NS
company_list[0][['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('ONGC')

# Plot for SEACOAST.NS
company_list[1][['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('SEACOAST')

# Plot for JETFREIGHT.NS
company_list[2][['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('JETFREIGHT')

# Plot for ITC.NS
company_list[3][['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('ITC')

fig.tight_layout()

# %%
# Finding the Percent change per day for each Stock
for company in company_list:
    company['Daily Return'] = company['Adj Close'].pct_change()

# Plotting the Daily Return Percentage
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

# Plot for ONGC.NS
company_list[0]['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('ONGC')

# Plot for SEACOAST.NS
company_list[1]['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('SEACOAST')

# Plot for JETFREIGHT.NS
company_list[2]['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('JETFREIGHT')

# Plot for ITC.NS
company_list[3]['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('ITC')

fig.tight_layout()

# %%
plt.figure(figsize=(12, 9))

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Daily Return'].hist(bins=50)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{company_name[i - 1]}')
    
plt.tight_layout()

# %%
# Adding all the Closing Prices into one dataframe

closing_df = pdr.get_data_yahoo(tech_list, start=start, end=end)['Adj Close']

# Making a new Tech Returns Dataframe
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# [**********************75%%**********            ]  3 of 4 completed
# C:\Users\athai\AppData\Local\Temp\ipykernel_27720\664773243.py:6: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   tech_rets = closing_df.pct_change()
# Ticker          AAPL    ITC.NS  JETFREIGHT.NS   ONGC.NS
# Date
# 2023-07-04       NaN       NaN            NaN       NaN
# 2023-07-05       NaN  0.018763      -0.013158  0.009926
# 2023-07-06  0.002509 -0.002526       0.013333  0.015970
# 2023-07-07 -0.005891 -0.011606      -0.013158 -0.011487
# 2023-07-10 -0.010856 -0.005444      -0.013333 -0.004587

# %%
# Comparing the Google Stock to itself to show a perfectly Linear Relationship
sns.jointplot(x='ONGC.NS', y='ONGC.NS', data=tech_rets, kind='scatter', color='seagreen')

# %%
# Comparing the Daily Returns of Google and Microsoft
sns.jointplot(x='ONGC.NS', y='AAPL', data=tech_rets, kind='scatter')

# %%
# Calling pairplot on the DataFrame for Automatic Visual Analysis of all the comparisions
sns.pairplot(tech_rets, kind='reg')

# %%
# Setting up the figure by nameing it returns_fig and calling PairPlot on the DataFrame
return_fig = sns.PairGrid(tech_rets.dropna())

# Using mpa_upper to specify the upper triangle
return_fig.map_upper(plt.scatter, color='purple')

return_fig.map_lower(sns.kdeplot, cmap='cool_d')

# Defining the Diagonal as a series of histogram plots of the daily returns
return_fig.map_diag(plt.hist, bins=30)

# %%
# Setting up the figure by nameing it returns_fig and calling PairPlot on the DataFrame
returns_fig = sns.PairGrid(closing_df)

# Using mpa_upper to specify the upper triangle
returns_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Defining the Diagonal as a series of histogram plots of the Closing DataFrame
returns_fig.map_diag(plt.hist,bins=30)

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(tech_rets.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock return')

plt.subplot(2, 2, 2)
sns.heatmap(closing_df.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock closing price')
# Out:
# Text(0.5, 1.0, 'Correlation of stock closing price')

# %%
rets = tech_rets.dropna()

area = np.pi * 20

plt.figure(figsize=(10, 8))
plt.scatter(rets.mean(), rets.std(), s=area)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(label, xy=(x, y), xytext=(50, 50), textcoords='offset points', ha='right', va='bottom', 
                 arrowprops=dict(arrowstyle='-', color='blue', connectionstyle='arc3,rad=-0.3'))

# %%
# Obtaining the Stock Quote
df = pdr.get_data_yahoo('ONGC.NS', start='2012-01-01', end=datetime.now())
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-02  171.666672  175.233337  170.966660  172.233337   96.398613
# 2012-01-03  174.066666  176.333328  173.100006  175.466660   98.208313
# 2012-01-04  176.000000  178.399994  174.066666  177.800003   99.514290
# 2012-01-05  178.966660  179.966660  174.000000  174.500000   97.667259
# 2012-01-06  170.933334  172.266663  169.100006  170.433334   97.724602
# ...                ...         ...         ...         ...         ...
# 2024-06-28  269.000000  275.450012  268.350006  274.200012  274.200012
# 2024-07-01  275.000000  275.799988  271.600006  272.950012  272.950012
# 2024-07-02  273.200012  279.799988  271.500000  274.850006  274.850006
# 2024-07-03  276.000000  277.700012  274.000000  274.700012  274.700012
# 2024-07-04  275.000000  278.899994  273.049988  277.049988  277.049988
#
#               Volume
# Date
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.show()

# %%
# Creating a new DataFrame with the Close Column
data = df.filter(['Close'])
# Converting DataFrame into Numpy Array
dataset = data.values
# Setting the number of rows to train the model on
training_data_len = int(np.ceil( len(dataset) * .95 ))

training_data_len
# Out:
# 2928

# %%
# Scaling the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.44815657],
#        [0.46106748],
#        [0.47038471],
#        ...,
#        [0.85791302],
#        [0.85731409],
#        [0.86669772]])

# %%
# Creating the scaled Training Data Set
train_data = scaled_data[0:int(training_data_len), :]
# Splitting the Training Data set into "x_train" and "y_train"
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i<= 61:
        print(x_train)
        print(y_train)
        print()
        
# Converting the "x_train" and "y_train" into Numpy Arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshaping the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
# Out:
# [array([0.44815657, 0.46106748, 0.47038471, 0.45720753, 0.44096902,
#        0.44509517, 0.4557434 , 0.45148412, 0.44669243, 0.45175032,
#        0.44256622, 0.45813927, 0.47451085, 0.48396115, 0.49500865,
#        0.49341144, 0.4903501 , 0.48595769, 0.50126453, 0.49460938,
#        0.49527491, 0.48569149, 0.49554111, 0.51018236, 0.51457477,
#        0.5224278 , 0.51430857, 0.50925069, 0.51044856, 0.50805275,
#        0.49540798, 0.50352727, 0.50925069, 0.50911756, 0.53733531,
#        0.53946498, 0.53334223, 0.51790232, 0.50858516, 0.51484098,
#        0.54092906, 0.52761882, 0.50951689, 0.51563958, 0.51271131,
#        0.50299481, 0.51350997, 0.49953419, 0.52588848, 0.5423932 ,
#        0.52322647, 0.48728876, 0.48622389, 0.48529222, 0.48329568,
#        0.4806336 , 0.47224811, 0.45747373, 0.46719023, 0.4465593 ])]
# [0.45361378635833727]
#
# [array([0.44815657, 0.46106748, 0.47038471, 0.45720753, 0.44096902,
#        0.44509517, 0.4557434 , 0.45148412, 0.44669243, 0.45175032,
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# Building the Long Short Term Memory Model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compiling the Model
model.compile(optimizer='adam', loss='mean_squared_error')

# Training the Model
# (Can Train the Model using only 1 EPOCH)
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# c:\Users\athai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2868/2868 ━━━━━━━━━━━━━━━━━━━━ 60s 20ms/step - loss: 0.0027

# %%
# Creating the Testing Data Set
test_data = scaled_data[training_data_len - 60: , :]
# Creating the testing data sets in "x_test" and "y_test"
x_test = []
y_test = dataset[training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    
# COnverting the Data into a Numpy Array
x_test = np.array(x_test)

# Reshaping the data
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# Getting the Models Predicted Price Value
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# Getting the Root Mean Squared Error
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))
rmse
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 11.454543553466575

# %%
# Plotting the data
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
# Visualizing the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\athai\AppData\Local\Temp\ipykernel_27720\2585788172.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
# Showing the Valid and Predicted Prices
valid
# Out:
#                  Close  Predictions
# Date
# 2023-11-16  201.800003   192.793564
# 2023-11-17  196.350006   194.823380
# 2023-11-20  197.850006   194.407990
# 2023-11-21  191.199997   194.059723
# 2023-11-22  191.000000   191.623047
# ...                ...          ...
# 2024-06-28  274.200012   258.085419
# 2024-07-01  272.950012   260.475128
# 2024-07-02  274.850006   262.025146
# 2024-07-03  274.700012   263.475494
# 2024-07-04  277.049988   264.213501
#
# [154 rows x 2 columns]
